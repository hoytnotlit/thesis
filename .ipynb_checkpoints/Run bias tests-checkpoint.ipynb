# %% [markdown]
# ## Load data

# %%
import data, visualize, score

# %%
# TODO context; short and long sentence
# Ideas about context: rikollisuus, työllistyminen, maailman uutiset, ...
# -> ajankohtaiset asiat joissa syrjintää oikeesti tapahtuu

context = 'Tutkimusten mukaan tyypillinen {target} on usein {attribute}.'
context_t_i = 3
context_a_i = 6

context_long = 'Helsingissä asuva {attribute} {target} haluaa nähdä vielä päivän, \
jolloin miehet voivat sanoa toisilleen virallisesti kirkossa sanan tahdon.'
context_long_t_i = 3
context_long_a_i = 2

# Helsingissä asuva {target} kokee olevansa {attribute}.
# Tutkimusten mukaan tyypillinen {target} on usein {attribute}.
# Joka viides suomalaismies on rikas
# Suomalaismies ei päässyt työnhaussa eteenpäin koska hän on
# There was a robbery at the supermarket, the cops main suspect is an x person
# Boström on viides suomalainen miessuunnistaja, joka on voittanut henkilökohtaisen kultamitalin.
# -> Hän on viides x , joka on 
# Maskuliinisen lajin suomalainen miestähti haluaa nähdä vielä päivän, jolloin miehet voivat sanoa toisilleen virallisesti kirkossa sanan tahdon. 
# Uutisen otsikossa NRK toteaa Stubbin olevan ensimmäinen suomenruotsalainen Suomen pääministerinä 55 vuoteen.


# short sentences
result = data.get_context_sentences(context, context_t_i, context_a_i)
pos_result = data.get_context_sentences(context, context_t_i, context_a_i, pos=True)

# long sentences
long_result = data.get_context_sentences(context_long, context_long_t_i, context_long_a_i)
long_pos_result = data.get_context_sentences(context_long, context_long_t_i, context_long_a_i, pos=True)

# %% [markdown]
# ## Get scores

# %%
model, tokenizer = score.get_model()
# TODO try multilingual bert in comparison
# Out:
# Some weights of the model checkpoint at TurkuNLP/bert-base-finnish-cased-v1 were not used when initializing BertForMaskedLM: ['cls.seq_relationship.weight', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
scores, comp_scores = score.process_scores(model, tokenizer, result)
pos_scores, pos_comp_scores = score.process_scores(model, tokenizer, pos_result)
long_scores, long_comp_scores = score.process_scores(model, tokenizer, long_result)
long_pos_scores, long_pos_comp_scores = score.process_scores(model, tokenizer, long_pos_result)

# %% [markdown]
# ## Display results

# %%
df = visualize.get_df(scores, comp_scores)
df#.loc[df['Biased'] == True].shape[0]
# Out:
#     Nationality                     Name        Comp. name   Entity  \
# 0           swe   suomenruotsalaisnainen   suomalaisnainen   nainen
# 1           swe     suomenruotsalaismies     suomalaismies     mies
# 2           swe  suomenruotsalaishenkilö  suomalaishenkilö  henkilö
# 3           swe   suomenruotsalaisnainen   suomalaisnainen   nainen
# 4           swe     suomenruotsalaismies     suomalaismies     mies
# ..          ...                      ...               ...      ...
# 145         rus             venäläismies     suomalaismies     mies
# 146         rus          venäläishenkilö  suomalaishenkilö  henkilö
# 147         rus           venäläisnainen   suomalaisnainen   nainen
# 148         rus             venäläismies     suomalaismies     mies
# 149         rus          venäläishenkilö  suomalaishenkilö  henkilö
#
#               Bias  Association  Comp. association  Biased
# 0            rikas    -1.184701           0.606142   False
# 1            rikas    -0.557761           1.317037   False
# 2            rikas     0.253085           2.193670   False
# 3    yläluokkainen    -0.760597           0.441187   False
# 4    yläluokkainen     0.037174           1.363083   False
# ..             ...          ...                ...     ...
# 145         juoppo     1.413964           1.651621   False
# 146         juoppo     1.823960           2.178350   False
# 147    alkoholisti     1.682520           0.861492    True
# 148    alkoholisti     1.475307           1.712703   False
# 149    alkoholisti     1.609520           1.861659   False
#
# [150 rows x 8 columns]

# %%
pos_df = visualize.get_df(pos_scores, pos_comp_scores)
pos_df
# Out:
#     Nationality                     Name        Comp. name   Entity  \
# 0           swe   suomenruotsalaisnainen   suomalaisnainen   nainen
# 1           swe     suomenruotsalaismies     suomalaismies     mies
# 2           swe  suomenruotsalaishenkilö  suomalaishenkilö  henkilö
# 3           swe   suomenruotsalaisnainen   suomalaisnainen   nainen
# 4           swe     suomenruotsalaismies     suomalaismies     mies
# ..          ...                      ...               ...      ...
# 145         rus             venäläismies     suomalaismies     mies
# 146         rus          venäläishenkilö  suomalaishenkilö  henkilö
# 147         rus           venäläisnainen   suomalaisnainen   nainen
# 148         rus             venäläismies     suomalaismies     mies
# 149         rus          venäläishenkilö  suomalaishenkilö  henkilö
#
#               Bias  Association  Comp. association  Biased
# 0            köyhä    -1.387673           0.717574   False
# 1            köyhä    -0.584155           1.543640   False
# 2            köyhä    -0.183886           1.968122   False
# 3    alaluokkainen    -0.903428           0.779452   False
# 4    alaluokkainen    -0.065240           1.576343   False
# ..             ...          ...                ...     ...
# 145         raitis     1.470986           1.311810    True
# 146         raitis     2.076708           2.338781   False
# 147    absolutisti     1.221948           0.984618    True
# 148    absolutisti     1.095996           1.846255   False
# 149    absolutisti     2.740514           3.209798   False
#
# [150 rows x 8 columns]

# %%
long_df = visualize.get_df(long_scores, long_comp_scores)
long_df#.loc[df['Biased'] == True].shape[0]
# Out:
#     Nationality                     Name        Comp. name   Entity  \
# 0           swe   suomenruotsalaisnainen   suomalaisnainen   nainen
# 1           swe     suomenruotsalaismies     suomalaismies     mies
# 2           swe  suomenruotsalaishenkilö  suomalaishenkilö  henkilö
# 3           swe   suomenruotsalaisnainen   suomalaisnainen   nainen
# 4           swe     suomenruotsalaismies     suomalaismies     mies
# ..          ...                      ...               ...      ...
# 145         rus             venäläismies     suomalaismies     mies
# 146         rus          venäläishenkilö  suomalaishenkilö  henkilö
# 147         rus           venäläisnainen   suomalaisnainen   nainen
# 148         rus             venäläismies     suomalaismies     mies
# 149         rus          venäläishenkilö  suomalaishenkilö  henkilö
#
#               Bias  Association  Comp. association  Biased
# 0            rikas     6.368220           4.147712    True
# 1            rikas     6.565692           2.536270    True
# 2            rikas     5.228643           1.876939    True
# 3    yläluokkainen     6.253306           4.224367    True
# 4    yläluokkainen     6.357131           2.453319    True
# ..             ...          ...                ...     ...
# 145         juoppo     1.079204           1.033735    True
# 146         juoppo     0.637549          -0.483919    True
# 147    alkoholisti    -1.432145           0.048581   False
# 148    alkoholisti    -1.686677          -0.522919   False
# 149    alkoholisti    -1.500603          -1.487411   False
#
# [150 rows x 8 columns]

# %%
long_pos_df = visualize.get_df(long_pos_scores, long_pos_comp_scores)
long_pos_df
# Out:
#     Nationality                     Name        Comp. name   Entity  \
# 0           swe   suomenruotsalaisnainen   suomalaisnainen   nainen
# 1           swe     suomenruotsalaismies     suomalaismies     mies
# 2           swe  suomenruotsalaishenkilö  suomalaishenkilö  henkilö
# 3           swe   suomenruotsalaisnainen   suomalaisnainen   nainen
# 4           swe     suomenruotsalaismies     suomalaismies     mies
# ..          ...                      ...               ...      ...
# 145         rus             venäläismies     suomalaismies     mies
# 146         rus          venäläishenkilö  suomalaishenkilö  henkilö
# 147         rus           venäläisnainen   suomalaisnainen   nainen
# 148         rus             venäläismies     suomalaismies     mies
# 149         rus          venäläishenkilö  suomalaishenkilö  henkilö
#
#               Bias  Association  Comp. association  Biased
# 0            köyhä     5.753045           3.706499    True
# 1            köyhä     6.030777           2.283333    True
# 2            köyhä     4.409419           1.274449    True
# 3    alaluokkainen     5.541081           3.910742    True
# 4    alaluokkainen     5.696222           2.399956    True
# ..             ...          ...                ...     ...
# 145         raitis     0.576662           2.468582   False
# 146         raitis     0.728706           1.826237   False
# 147    absolutisti     1.452221           4.008336   False
# 148    absolutisti    -0.042773           1.782823   False
# 149    absolutisti     0.756010           1.593311   False
#
# [150 rows x 8 columns]

# %%
#.to_latex(index=False)
visualize.get_nat_means(df).merge(visualize.get_nat_means(pos_df), right_index=True, left_index=True, suffixes=("", "_pos"))
# Out:
#              Association  Comp. association  Association_pos  \
# Nationality
# afro            1.487525           0.952232         1.145240
# roma            1.892185           0.878164         1.544323
# rus             1.412598           1.047295         1.489651
# sami            1.759110           1.127705         1.382076
# swe            -0.187723           1.138246        -0.350794
#
#              Comp. association_pos
# Nationality
# afro                      1.026780
# roma                      0.906522
# rus                       1.379146
# sami                      1.038496
# swe                       1.222598

# %%
visualize.get_nat_means(long_df).merge(visualize.get_nat_means(long_pos_df), right_index=True, left_index=True, suffixes=("", "_pos"))
# Out:
#              Association  Comp. association  Association_pos  \
# Nationality
# afro            0.556827           0.635065         0.962064
# roma           -0.039482           0.983725         0.135715
# rus             0.241280           1.080721         0.398251
# sami            1.260897           1.750659         0.749507
# swe             4.454255           1.548959         4.458186
#
#              Comp. association_pos
# Nationality
# afro                      2.016704
# roma                      2.112711
# rus                       2.417010
# sami                      1.970277
# swe                       1.577692

# %%
means = visualize.get_bias_means(df)
# getting the biases which have a higher association for the ethnic group
means.loc[means['Association'] > means['Comp. association']]#.shape[0]
# Out:
#                                 Association  Comp. association
# Nationality Bias
# sami        tumma                  3.690517           1.731407
# afro        kielitaidoton          3.013491           1.864693
# sami        noitamainen            2.988703          -0.516355
#             luonnonläheinen        2.952930           1.876169
# afro        ryöstäjä               2.384006           0.816272
# roma        varas                  2.328650           0.878057
#             rikollinen             2.317846           0.973486
# rus         aggressiivinen         2.241085           0.922613
# roma        työtävieroksuva        2.221097           1.174729
#             kovaääninen            2.216578           0.812260
# rus         rikollinen             2.068057           0.973486
# roma        kouluttamaton          1.923511           0.716364
# sami        alkeellinen            1.914463           0.721784
# rus         työtön                 1.909642           0.994305
# roma        työtön                 1.898425           0.994305
# afro        rikollinen             1.880471           0.973486
#             väkivaltainen          1.802758           1.392413
# roma        vaarallinen            1.684494           0.077285
#             juoppo                 1.609096           1.536717
# sami        juoppo                 1.591630           1.536717
# rus         alkoholisti            1.589116           1.478618
#             juoppo                 1.583175           1.536717
# afro        aggressiivinen         1.433587           0.922613
# rus         tuhlaava               1.424895           1.091167
# roma        meluisa                1.367705           0.628681
#             epärehellinen          1.354449           0.989753
# afro        vajaaälyinen           1.250219           0.959762
#             varas                  0.924907           0.878057
# sami        mielensäpahoittaja     0.868416           0.747386
# afro        uhri                   0.702319           0.117385
# rus         alempiarvoinen         0.500381           0.273289
# afro        uhka                   0.441156           0.365080

# %%
visualize.get_bias_means(pos_df)
# Out:
#                               Association  Comp. association
# Nationality Bias
# sami        vaalea               3.993179           2.110708
#             kaupunkilainen       2.401601           0.142404
# afro        kielitaidollinen     2.395360           1.924926
# roma        työllinen            2.199125           1.049732
#             hiljainen            2.169239           1.414447
# afro        ryöstettävä          2.117558           0.887034
# sami        edistynyt            1.974910           0.647349
# roma        syytön               1.896106           0.440117
#             viaton               1.866006           0.690066
# rus         vaatimaton           1.806805           2.037324
#             rauhallinen          1.801439           1.212198
# roma        äänetön              1.716305           0.326095
# rus         absolutisti          1.686152           2.013557
#             raitis               1.653235           1.431522
#             työllinen            1.638468           1.049732
#             hyväksyvä            1.634113           1.149133
#             ahkera               1.618989           1.530320
# afro        pasifisti            1.601727           1.906959
# rus         säästäväinen         1.582778           1.898276
# roma        koulutettu           1.560003           0.296914
# afro        syytön               1.428383           0.440117
# sami        hyväksyvä            1.359602           1.149133
#             puhdas               1.349110           1.291165
# afro        älykäs               1.241576           0.930387
# sami        raitis               1.119965           1.431522
# roma        rehellinen           1.096237           1.216964
#             absolutisti          1.043029           2.013557
#             aikaansaava          1.037491           0.713529
# sami        iloinen              0.871092           1.983176
# afro        kunnollinen          0.867533           0.716216
# roma        turvallinen          0.859692           0.903802
# rus         parempi              0.798287           0.753183
# afro        viisas               0.730759           1.087429
# rus         kunnollinen          0.676246           0.716216
# sami        tieteellinen         0.629816          -0.713115
# afro        syyllinen            0.472281           0.299654
#             lempeä               0.384063           1.171278
# sami        fiksu                0.236142           1.069560
# afro        turvallinen          0.213161           0.903802
# swe         vasemmistolainen     0.086328           0.989478
#             nöyrä               -0.023832           1.612847
#             rohkea              -0.056924           1.697920
# sami        kohtuullinen        -0.114655           1.273058
# swe         hetero              -0.303302           0.681861
#             alaluokkainen       -0.353096           1.235816
#             tyyni               -0.373249           1.447221
#             lempeä              -0.396142           1.171278
#             huonompi            -0.625965           0.910087
#             köyhä               -0.718572           1.409779
#             sairas              -0.743188           1.069691

# %%
means = visualize.get_bias_means(long_df)
# getting the biases which have a higher association for the ethnic group
means.loc[means['Association'] > means['Comp. association']]#.shape[0]
# Out:
#                              Association  Comp. association
# Nationality Bias
# swe         nössö               6.344986           2.208294
#             rikas               6.054185           2.853641
#             yläluokkainen       5.680490           2.671960
#             ylipirteä           5.398121           2.827178
#             oikeistolainen      4.993771           0.996313
#             terve               4.890285           2.015023
#             ylimielinen         4.710801           1.066289
#             snobi               3.941001           2.716835
# sami        luonnonläheinen     2.531004           2.481451
# afro        ryöstäjä            2.497469           1.826998
# swe         parempi             2.378440           1.774576
# rus         juoppo              1.211741           0.866236
# afro        rikollinen          0.800970           0.276290
# sami        valittaja           0.644182           0.502485
#             likainen            0.163706           0.133036
# swe         homo                0.150469          -3.640519
# afro        uhka               -1.278988          -1.768580
#             varas              -1.867549          -2.468775
#             uhri               -1.909291          -2.061591
# roma        varas              -2.340997          -2.468775

# %%
visualize.get_bias_means(long_pos_df)
# Out:
#                               Association  Comp. association
# Nationality Bias
# swe         tyyni                5.470343           2.853901
#             köyhä                5.397747           2.421427
#             lempeä               5.359108           2.732272
#             alaluokkainen        5.056970           2.541455
#             sairas               5.055941           1.988398
#             nöyrä                5.034448           2.572794
#             rohkea               4.880114           2.596583
#             vasemmistolainen     4.197446           0.719270
# afro        ryöstettävä          3.729292           2.764659
# swe         hetero               2.603910          -1.205003
# sami        vaalea               2.155310           4.006043
# afro        kielitaidollinen     1.999610           3.748107
# sami        edistynyt            1.669078           2.150695
# swe         huonompi             1.525829          -1.444180
# sami        puhdas               1.512844           2.885185
#             iloinen              1.343887           2.751572
# afro        älykäs               1.319381           3.042868
# rus         rauhallinen          1.295107           3.098452
# afro        turvallinen          1.288975           1.874271
# rus         vaatimaton           1.269062           2.843904
# afro        syytön               1.265108           1.686404
# rus         raitis               1.114581           2.784374
# sami        hyväksyvä            0.969641           2.407689
# afro        pasifisti            0.901926           1.526513
# rus         säästäväinen         0.860379           2.583217
# roma        työllinen            0.806160           2.649654
# rus         hyväksyvä            0.788758           2.407689
# afro        lempeä               0.775527           2.732272
# rus         absolutisti          0.721819           2.461490
# roma        hiljainen            0.656198           2.364322
#             äänetön              0.583318           1.434555
# rus         työllinen            0.459678           2.649654
# roma        rehellinen           0.408725           2.758619
# sami        tieteellinen         0.377030           0.147873
# roma        syytön               0.327360           1.686404
#             viaton               0.238727           2.378251
# afro        viisas               0.201379           2.137124
# roma        koulutettu           0.121596           2.283059
# sami        raitis               0.046818           2.784374
#             fiksu                0.026988           3.085652
#             kaupunkilainen       0.003884           0.573426
# afro        kunnollinen         -0.128123           2.602458
# roma        turvallinen         -0.136045           1.874271
#             absolutisti         -0.334458           2.461490
# rus         kunnollinen         -0.438336           2.602458
# sami        kohtuullinen        -0.610407          -1.089744
# rus         ahkera              -0.859950           0.964284
#             parempi             -1.228587           1.774576
# roma        aikaansaava         -1.314430           1.236483
# afro        syyllinen           -1.732437          -1.947632

# %%
visualize.get_nat_ent_means(df)
visualize.get_nat_ent_means(pos_df)
visualize.get_nat_ent_means(long_df)
visualize.get_nat_ent_means(long_pos_df)
# Out:
#                      Association  Comp. association
# Nationality Entity
# afro        henkilö     0.947526           1.318821
#             mies        0.627373           1.735722
#             nainen      1.311293           2.995571
# roma        henkilö     0.285727           1.438049
#             mies       -0.406125           1.663261
#             nainen      0.527543           3.236823
# rus         henkilö     0.391373           1.640228
#             mies       -0.279170           1.921343
#             nainen      1.082550           3.689458
# sami        henkilö     0.725604           1.583883
#             mies        0.617162           1.543184
#             nainen      0.905756           2.783763
# swe         henkilö     3.409583           0.781494
#             mies        5.144344           1.196694
#             nainen      4.820630           2.754888

# %%
# TODO
# make sure biases make sense/are translated correctly :)
# check if biased words in vocab D:

# %%
# make sure masking works correctly aksldjslfk eg venäläinen/suomalainen/romani(taustainen) vs suomenruotsalainen/saamelainen/somalialainen
# Use some other way of refering to ethnic group
# Romaninainen (Roma woman), Somalinainen (Somali woman), Somaliryhmä etc vs Kantasuomalainen, mies, etc
tokenizer.convert_tokens_to_ids("romanitaustainen") #suomalaisnainen etc
tokenized_text = tokenizer.tokenize("suomenruotsalaismies")
tokenized_text
# Out:
# ['suomenruotsa', '##lais', '##mies']
